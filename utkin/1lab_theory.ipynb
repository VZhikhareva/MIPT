# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.arange(-0.5, 1.5, 0.01)
y = -(7/9)*(x-5/7)
y1 = (-4/15)*(x-3/4)
x_inter = 16/23
y_inter =  round((-7/9)*(x_inter-5/7), 4)
#x3 = np.arange(-3, 3.0 , 0.001)
y3 = (-21/45)*(x-5/21)
plt.plot(x, y, 'b--', linewidth = '1.6')
plt.plot(x, y1, 'r--', linewidth = '1.6')
plt.plot(x, y3, color = 'orange', linewidth = '1.6')

plt.axhline(y = 0, xmin = 0, xmax = 10, linewidth = '0.7', color = 'green')
plt.axvline(x = 0, ymin = 0, ymax = 10, linewidth = '0.7', color = 'green')
plt.grid(1, 'both')
plt.savefig('lab1.png')
xd = (-14/411) ### точка наиболее близкая ко первому порядку аппрокимации среди монотонных по Фридрихсу
yd = (87/685)    
plt.scatter(xd, yd, s = 15, color = 'black') #точка наиболее близкая к первому порядку
                                                #аппрокимации среди монотонных по Фридрихсу
xb = 0
yb = 5/9
xa  = 0
ya = 1/5
plt.scatter(xb, yb, s= 15, color = 'b')
plt.scatter(x_inter, y_inter, s= 15, color = 'r')
x5 = (xd, 0)
y5 = (yd, 1/5)
plt.plot(x5, y5, 'black')
plt.scatter(xa, ya, color = 'r', s = 15)
vert_x = (0, 0)
vert_y = (ya, yb)
plt.plot(vert_x, vert_y, 'grey')

# plt.xlabel('')
# plt.ylabel('Probability')
plt.title('Графическое представление пп. 1-5')
plt.text(0.01, 0.6, r'B')
plt.text(0.01, 0.22, r'A')
plt.text(0.7, 0.02, r'C')
plt.text(-0.11, 0.11, r'D')
#plt.axis([0, 160, 0, 0.03])
#plt.grid(True)
plt.xlabel(r'$\alpha_{-1}^{-1}$')
plt.ylabel(r'$\alpha_{-1}^{1}$')
 
x33 = 10/21
y33 = -1/9
plt.scatter(x33, y33, color = 'black')
plt.scatter(5/21, 0, color = 'black', size  = 10 )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-c627ed4fae0d> in <module>
#      47 y33 = -1/9
#      48 plt.scatter(x33, y33, color = 'black')
# ---> 49 plt.scatter(5/21, 0, color = 'black', size  = 10 )
#      50 plt.show()
#
# c:\users\potas\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, data, **kwargs)
#    2860         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2861         verts=verts, edgecolors=edgecolors, **({"data": data} if data
# -> 2862         is not None else {}), **kwargs)
#    2863     sci(__ret)
#    2864     return __ret
#
# c:\users\potas\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
x = 130/411#257*5/(137*21)
y = -5/137#-40/411
print(y-(1/9-7*x/15))


xd = 1/3
yd = 0
vv = [x - xd, y - yd]
zz = [-5/21, 1/9]

print(vv[1] * zz[1] + vv[0] * zz[0])
# Out:
# 1.3877787807814457e-17
# -5.204170427930421e-18

# %%
x = np.arange(-0.25, 0.8, 0.01)
y = 5/9 - 7/9 * x
y1 = 1/5 - 3/5*x
y2 = 1/9 - 7*x/15
 
# точка M
xm = 130/411
ym = -5/137

# точка A
xa  = 0
ya = 1/5

# точка B
xb = 0
yb = 5/9

# точка C
xc = 5/7
yc = 0

# точка D
xd = 1/3
yd = 0

# точка F
xf = 0
yf =1/9

# перпендикуляр DM
perp_x = (xd, xm)
perp_y = (yd, ym)


plt.plot(x, y, 'b', linewidth = '1.6', label = r'$\alpha_{0}^{0} = 0$')
plt.plot(x, y1, 'r', linewidth = '1.6', label = r'$ \alpha_{1}^{0} =  0$')
plt.plot(x, y2, color = 'orange', linewidth = '1.6', label = r'$1/9 - 7/15\alpha_{-1}^{-1}$')
plt.plot(perp_x, perp_y, color = 'black', linewidth = '1.8')


plt.axhline(y = 0, xmin = 0, xmax = 10, linewidth = '0.7', color = 'green')
plt.axvline(x = 0, ymin = 0, ymax = 10, linewidth = '0.7', color = 'green')
plt.grid(1, 'both')

   
plt.scatter(xd, yd, s = 15, color = 'black') #точка наиболее близкая к первому порядку
                                                #аппрокимации среди монотонных по Фридрихсу
gor_x = (xd, xc)
gor_y = (yd, yc)
plt.plot(gor_x, gor_y, 'grey', linewidth = '3')

plt.scatter(xb, yb, s= 15, color = 'b')
plt.scatter(xa, ya, color = 'r', s = 15)
vert_x = (0, 0)
vert_y = (ya, yb)
plt.plot(vert_x, vert_y, 'grey', linewidth = '3')
plt.scatter(xm, ym, color = 'orange', s = 20)
plt.scatter(xc, yc, color = 'blue', s = 20)

plt.xlabel('')
plt.ylabel('Probability')
plt.title('Графическое представление пп. 1-5')
plt.text(xb, yb+0.03, r'B')
plt.text(xa +  0.01, ya+0.03, r'A')
plt.text(xc, yc+0.03, r'C')
plt.text(xd, yd+0.03, r'D')
plt.text(xm, ym-0.05, r'M')
plt.grid(True)
plt.xlabel(r'$\alpha_{-1}^{-1}$')
plt.ylabel(r'$\alpha_{-1}^{1}$')



### 3 порядок аппроксимации

plt.scatter(10/21, -1/9, color = 'black', s = 15)
plt.text(10/21, -1/9-0.06, r'E')

plt.legend()


plt.savefig('lab2.png')
plt.show()
